# %% [markdown]
# ### Data Visualization
#
# **OBJECTIVES**
#
# - Review loading and manipulating data with `pandas`
# - Review plotting with `matplotlib` and `seaborn`
# - Discuss visualization for categorical and continuous data

# %% [markdown]
# ### Example Data
#
# - `.csv` files from kaggle
# - `.jpeg` files from local machine
# - `.txt` files from local machine
# - `.csv` files from github

# %%
url = 'https://raw.githubusercontent.com/owid/covid-19-data/master/public/data/owid-covid-data.csv'

# %%
import pandas as pd

# %%
stroke_df = pd.read_csv('data/healthcare-dataset-stroke-data.csv')

# %%
stroke_df.head()
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21   NaN     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 3        Private          Urban             171.23  34.4           smokes
# 4  Self-employed          Rural             174.12  24.0     never smoked
#
#    stroke
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
vaccine_df = pd.read_csv(url)

# %%
vaccine_df.head(2)
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-02-24          1.0        1.0
# 1      AFG      Asia  Afghanistan  2020-02-25          1.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         NaN                  NaN  ...
# 1                 NaN           NaN         NaN                  NaN  ...
#
#    gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 0        1803.987              NaN                597.029
# 1        1803.987              NaN                597.029
#
#    diabetes_prevalence  female_smokers  male_smokers  handwashing_facilities  \
# 0                 9.59             NaN           NaN                  37.746
# 1                 9.59             NaN           NaN                  37.746
#
#    hospital_beds_per_thousand  life_expectancy  human_development_index
# ...

# %%
pd.read_table('data/sample.txt', header = None)
# Out:
#                                      0
# 0  This is just a sample of some text.
# 1            This is more sample text.

# %%
with open('data/sample.txt') as f:
    sents = f.readlines()

# %%
sents
# Out:
# ['This is just a sample of some text.\n', 'This is more sample text.']

# %%
import matplotlib.pyplot as plt

# %%
dog = plt.imread('data/len_3.jpg')

# %%
plt.imshow(dog)

# %%
import os

# %%
os.listdir('data')
# Out:
# ['netflix_titles.csv.zip',
#  'len_3.jpg',
#  'insults.csv',
#  'healthcare-dataset-stroke-data.csv',
#  'mtcars.csv',
#  '.ipynb_checkpoints',
#  'sample.txt']

# %% [markdown]
# ### Categorical vs. Continuous

# %%
stroke_df.head()
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21   NaN     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 3        Private          Urban             171.23  34.4           smokes
# 4  Self-employed          Rural             174.12  24.0     never smoked
#
#    stroke
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
stroke_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5110 entries, 0 to 5109
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5110 non-null   int64
#  1   gender             5110 non-null   object
#  2   age                5110 non-null   float64
#  3   hypertension       5110 non-null   int64
#  4   heart_disease      5110 non-null   int64
#  5   ever_married       5110 non-null   object
#  6   work_type          5110 non-null   object
#  7   Residence_type     5110 non-null   object
#  8   avg_glucose_level  5110 non-null   float64
#  9   bmi                4909 non-null   float64
#  10  smoking_status     5110 non-null   object
#  11  stroke             5110 non-null   int64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 479.2+ KB

# %%
stroke_df['gender'].value_counts().plot(kind = 'barh')
# Out:
# <AxesSubplot:>

# %%
import seaborn as sns

# %%
sns.countplot(x='gender', data = stroke_df)
# Out:
# <AxesSubplot:xlabel='gender', ylabel='count'>

# %%
sns.countplot(x = 'ever_married', data = stroke_df)
# Out:
# <AxesSubplot:xlabel='ever_married', ylabel='count'>

# %%
sns.displot(stroke_df, x = 'age')

# %%
sns.displot(stroke_df, x = 'age', kind = 'kde')

# %%
plt.boxplot(stroke_df['age'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7fe931a95430>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7fe931ab4880>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7fe931a95c70>],
#  'medians': [<matplotlib.lines.Line2D at 0x7fe9544e29a0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7fe9544e2d00>],
#  'means': []}

# %%
sns.boxplot(x =stroke_df['age'])
# Out:
# <AxesSubplot:xlabel='age'>

# %%
sns.violinplot(x = stroke_df['age'])
# Out:
# <AxesSubplot:xlabel='age'>

# %%
fig, ax = plt.subplots(2, 1, figsize = (15, 6))
sns.boxplot(x = stroke_df['age'], ax = ax[0])
sns.kdeplot(data = stroke_df, x = 'age', ax = ax[1])
# Out:
# <AxesSubplot:xlabel='age', ylabel='Density'>

# %%
sns.boxplot(x = 'stroke', y = 'age', data = stroke_df)
# Out:
# <AxesSubplot:xlabel='stroke', ylabel='age'>

# %%
sns.boxplot(x = 'work_type', y = 'age', hue = 'stroke', data = stroke_df)
# Out:
# <AxesSubplot:xlabel='work_type', ylabel='age'>

# %%
sns.kdeplot(x = 'age', hue = 'stroke', data = stroke_df)
# Out:
# <AxesSubplot:xlabel='age', ylabel='Density'>

# %%
sns.countplot(stroke_df['stroke'])
# Out:
# /Users/jacobkoehler/opt/anaconda3/envs/for_ds/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='stroke', ylabel='count'>
